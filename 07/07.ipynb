# %% [markdown]
# ## Day 7
# ### Part 1

# %%
with open("input.txt", "r") as f:
  file_content = f.read().splitlines()

# %%
# #sample
# with open("sample.txt", "r") as f:
#   file_content = f.read().splitlines()

# %%
separate_types = [x.split() for x in file_content]
separate_types
# Out:
# [['$', 'cd', '/'],
#  ['$', 'ls'],
#  ['dir', 'cmvqf'],
#  ['dir', 'dcgbjvj'],
#  ['57426', 'gszshjwr.lrs'],
#  ['dir', 'nsgms'],
#  ['124423', 'rjqns.prb'],
#  ['dir', 'wqvv'],
#  ['$', 'cd', 'cmvqf'],
#  ['$', 'ls'],
#  ['6852', 'cnsb.cmm'],
#  ['319810', 'cwqbmjb.vpl'],
#  ['dir', 'dcgbjvj'],
#  ['dir', 'ddnclwtd'],
#  ['dir', 'gccnrw'],
#  ['dir', 'qwzphd'],
#  ['dir', 'rvqwnjv'],
#  ['dir', 'ssmf'],
#  ['107040', 'trttdw.jsn'],
#  ['dir', 'wcn'],
#  ['296426', 'wqvv'],
#  ['$', 'cd', 'dcgbjvj'],
#  ['$', 'ls'],
#  ['dir', 'dcgbjvj'],
#  ['dir', 'rlvcvj'],
#  ['$', 'cd', 'dcgbjvj'],
#  ['$', 'ls'],
#  ['214674', 'gsqcwfmz.hlm'],
#  ['$', 'cd', '..'],
#  ['$', 'cd', 'rlvcvj'],
#  ['$', 'ls'],
#  ['151752', 'cnsb.cmm'],
#  ['256829', 'sjlwgf.mqn'],
#  ['$', 'cd', '..'],
#  ['$', 'cd', '..'],
#  ['$', 'cd', 'ddnclwtd'],
#  ['$', 'ls'],
#  ['177893', 'fpwznlp.zsf'],
#  ['$', 'cd', '..'],
#  ['$', 'cd', 'gccnrw'],
#  ['$', 'ls'],
#  ['dir', 'mbfw'],
#  ['dir', 'rlvcvj'],
# ...

# %%
# wrong - multiple folders with same name...

path_log = ["root"]
parent_folders = {}
for i in separate_types:

  current_folder = path_log[-1]
  path_address= "-".join(path_log)
  if i[0]=="$":
#    print ("order")
    if i[1]=="cd":
#      print("change directory")
      if i[2]=="/":
        path_log=["root"]
      elif i[2]=="..":
        path_log.pop()
        print(path_log)
      else:
        path_log.append(i[2])  
        print(path_log)
    elif i[1]=="ls":
      pass
      
  elif i[0] == "dir":
    if path_address not in parent_folders:
      parent_folders[path_address] = [0]
    else:
      parent_folders[path_address].append(0)
  else:
    if path_address not in parent_folders:
      parent_folders[path_address] = [int(i[0])]
    else:
      parent_folders[path_address].append(int(i[0]))
# Out:
# ['root', 'cmvqf']
# ['root', 'cmvqf', 'dcgbjvj']
# ['root', 'cmvqf', 'dcgbjvj', 'dcgbjvj']
# ['root', 'cmvqf', 'dcgbjvj']
# ['root', 'cmvqf', 'dcgbjvj', 'rlvcvj']
# ['root', 'cmvqf', 'dcgbjvj']
# ['root', 'cmvqf']
# ['root', 'cmvqf', 'ddnclwtd']
# ['root', 'cmvqf']
# ['root', 'cmvqf', 'gccnrw']
# ['root', 'cmvqf', 'gccnrw', 'mbfw']
# ['root', 'cmvqf', 'gccnrw', 'mbfw', 'dcgbjvj']
# ['root', 'cmvqf', 'gccnrw', 'mbfw', 'dcgbjvj', 'npjmq']
# ['root', 'cmvqf', 'gccnrw', 'mbfw', 'dcgbjvj']
# ['root', 'cmvqf', 'gccnrw', 'mbfw']
# ['root', 'cmvqf', 'gccnrw', 'mbfw', 'mhnjvrl']
# ['root', 'cmvqf', 'gccnrw', 'mbfw']
# ['root', 'cmvqf', 'gccnrw']
# ['root', 'cmvqf', 'gccnrw', 'rlvcvj']
# ['root', 'cmvqf', 'gccnrw']
# ['root', 'cmvqf', 'gccnrw', 'wsrdh']
# ['root', 'cmvqf', 'gccnrw', 'wsrdh', 'mgmp']
# ['root', 'cmvqf', 'gccnrw', 'wsrdh', 'mgmp', 'whzjb']
# ['root', 'cmvqf', 'gccnrw', 'wsrdh', 'mgmp']
# ['root', 'cmvqf', 'gccnrw', 'wsrdh']
# ['root', 'cmvqf', 'gccnrw']
# ...

# %%
len(parent_folders)
keys_folders = parent_folders.keys()
subtotals = {}
for fkey in keys_folders:
#  print(fkey,sum(parent_folders[fkey]))
  for key, val in parent_folders.items():
    if key.startswith(fkey):
      if fkey in subtotals:
        subtotals[fkey] += sum(val)
      else:
        subtotals[fkey] = sum(val)

# %%
up_to_hundred = []
for key, val in subtotals.items():
  if val <=100000:
    up_to_hundred.append(val)
print(sum(up_to_hundred))
# Out:
# 1454188

# %% [markdown]
# ### Part 2

# %%
subtotals['root']-70000000+30000000
# Out:
# 3837783

# %%
smallest = None
for key, val in subtotals.items():

  if val >3837783:
    if smallest is None:
      smallest= val
    elif smallest>val:

      smallest = val
print(smallest)
# Out:
# 4183246
